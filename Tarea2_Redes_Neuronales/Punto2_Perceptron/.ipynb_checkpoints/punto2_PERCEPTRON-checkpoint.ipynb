# %% [markdown]
# # Tarea 2. NN with Perceptron, Problema 2
#
# ## Fundamentos de inteligencia computacional
# ## por: Juan Pablo Arango A. & Simón Zapata Caro

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pydoc import help  # can type in the python console `help(name of function)` to get the documentation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from scipy import stats
from IPython.display import display, HTML
from pandas.tools.plotting import scatter_matrix
from matplotlib.artist import setp
import time

plt.rcParams['figure.figsize'] = (10,16)

# %%
df1     = pd.io.excel.read_excel("DatosPunto2.xlsx", sheetname=0)
letters = df1.iloc[:,0].copy()
df1 = df1.iloc[:,1:16].copy()
#normalización min-max
str_comp = 'ARNGOZPT'
df1 = (df1-np.min(df1, axis = 0))/(np.max(df1, axis = 0)-np.min(df1, axis = 0))
#df1 = (df1-np.mean(df1, axis = 0))/(np.std(df1, axis = 0))
X = np.array(df1)

y = -np.ones((X.shape[0],))
i = 0
for L in letters:
    if str_comp.find(L) >= 0:
        print('letra '+str(L)+' aparece en apellidos')
        y[i] = 1
    else:
        print('letra '+str(L)+' no aparece en apellidos')
    i += 1
X
# Out:
# letra T aparece en apellidos
# letra I no aparece en apellidos
# letra D no aparece en apellidos
# letra N aparece en apellidos
# letra G aparece en apellidos
# letra S no aparece en apellidos
# letra B no aparece en apellidos
# letra A aparece en apellidos
# letra J no aparece en apellidos
# letra M no aparece en apellidos
# letra X no aparece en apellidos
# letra O aparece en apellidos
# letra G aparece en apellidos
# letra M no aparece en apellidos
# letra R aparece en apellidos
# letra F no aparece en apellidos
# letra O aparece en apellidos
# letra C no aparece en apellidos
# letra T aparece en apellidos
# letra J no aparece en apellidos
# letra J no aparece en apellidos
# letra H no aparece en apellidos
# letra S no aparece en apellidos
# letra O aparece en apellidos
# letra J no aparece en apellidos
# letra C no aparece en apellidos
# letra M no aparece en apellidos
# letra W no aparece en apellidos
# letra H no aparece en apellidos
# letra G aparece en apellidos
# letra L no aparece en apellidos
# letra L no aparece en apellidos
# letra X no aparece en apellidos
# letra B no aparece en apellidos
# letra M no aparece en apellidos
# letra G aparece en apellidos
# letra O aparece en apellidos
# letra P aparece en apellidos
# letra G aparece en apellidos
# letra E no aparece en apellidos
# letra X no aparece en apellidos
# letra E no aparece en apellidos
# letra X no aparece en apellidos
# letra G aparece en apellidos
# letra V no aparece en apellidos
# letra X no aparece en apellidos
# letra W no aparece en apellidos
# letra G aparece en apellidos
# letra R aparece en apellidos
# letra S no aparece en apellidos
# letra Y no aparece en apellidos
# letra L no aparece en apellidos
# letra Y no aparece en apellidos
# letra J no aparece en apellidos
# letra S no aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra D no aparece en apellidos
# letra C no aparece en apellidos
# letra L no aparece en apellidos
# letra N aparece en apellidos
# letra C no aparece en apellidos
# letra E no aparece en apellidos
# letra X no aparece en apellidos
# letra H no aparece en apellidos
# letra L no aparece en apellidos
# letra H no aparece en apellidos
# letra E no aparece en apellidos
# letra Y no aparece en apellidos
# letra H no aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra J no aparece en apellidos
# letra J no aparece en apellidos
# letra D no aparece en apellidos
# letra R aparece en apellidos
# letra M no aparece en apellidos
# letra A aparece en apellidos
# letra N aparece en apellidos
# letra M no aparece en apellidos
# letra P aparece en apellidos
# letra C no aparece en apellidos
# letra P aparece en apellidos
# letra N aparece en apellidos
# letra W no aparece en apellidos
# letra V no aparece en apellidos
# letra V no aparece en apellidos
# letra M no aparece en apellidos
# letra E no aparece en apellidos
# letra N aparece en apellidos
# letra Y no aparece en apellidos
# letra W no aparece en apellidos
# letra O aparece en apellidos
# letra N aparece en apellidos
# letra H no aparece en apellidos
# letra O aparece en apellidos
# letra N aparece en apellidos
# letra H no aparece en apellidos
# letra U no aparece en apellidos
# letra Y no aparece en apellidos
# letra S no aparece en apellidos
# letra S no aparece en apellidos
# letra T aparece en apellidos
# letra C no aparece en apellidos
# letra V no aparece en apellidos
# letra T aparece en apellidos
# letra K no aparece en apellidos
# letra D no aparece en apellidos
# letra W no aparece en apellidos
# letra I no aparece en apellidos
# letra E no aparece en apellidos
# letra F no aparece en apellidos
# letra I no aparece en apellidos
# letra H no aparece en apellidos
# letra U no aparece en apellidos
# letra C no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra Z aparece en apellidos
# letra X no aparece en apellidos
# letra N aparece en apellidos
# letra R aparece en apellidos
# letra B no aparece en apellidos
# letra B no aparece en apellidos
# letra U no aparece en apellidos
# letra J no aparece en apellidos
# letra F no aparece en apellidos
# letra M no aparece en apellidos
# letra H no aparece en apellidos
# letra A aparece en apellidos
# letra O aparece en apellidos
# letra E no aparece en apellidos
# letra U no aparece en apellidos
# letra A aparece en apellidos
# letra X no aparece en apellidos
# letra S no aparece en apellidos
# letra J no aparece en apellidos
# letra K no aparece en apellidos
# letra I no aparece en apellidos
# letra P aparece en apellidos
# letra T aparece en apellidos
# letra C no aparece en apellidos
# letra H no aparece en apellidos
# letra A aparece en apellidos
# letra L no aparece en apellidos
# letra T aparece en apellidos
# letra A aparece en apellidos
# letra V no aparece en apellidos
# letra U no aparece en apellidos
# letra I no aparece en apellidos
# letra Z aparece en apellidos
# letra V no aparece en apellidos
# letra M no aparece en apellidos
# letra L no aparece en apellidos
# letra O aparece en apellidos
# letra B no aparece en apellidos
# letra A aparece en apellidos
# letra K no aparece en apellidos
# letra H no aparece en apellidos
# letra T aparece en apellidos
# letra W no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra E no aparece en apellidos
# letra M no aparece en apellidos
# letra B no aparece en apellidos
# letra M no aparece en apellidos
# letra Y no aparece en apellidos
# letra V no aparece en apellidos
# letra S no aparece en apellidos
# letra C no aparece en apellidos
# letra H no aparece en apellidos
# letra U no aparece en apellidos
# letra P aparece en apellidos
# letra Z aparece en apellidos
# letra E no aparece en apellidos
# letra N aparece en apellidos
# letra P aparece en apellidos
# letra H no aparece en apellidos
# letra T aparece en apellidos
# letra B no aparece en apellidos
# letra U no aparece en apellidos
# letra S no aparece en apellidos
# letra F no aparece en apellidos
# letra J no aparece en apellidos
# letra R aparece en apellidos
# letra E no aparece en apellidos
# letra P aparece en apellidos
# letra I no aparece en apellidos
# letra K no aparece en apellidos
# letra D no aparece en apellidos
# letra B no aparece en apellidos
# letra H no aparece en apellidos
# letra M no aparece en apellidos
# letra P aparece en apellidos
# letra O aparece en apellidos
# letra S no aparece en apellidos
# letra K no aparece en apellidos
# letra V no aparece en apellidos
# letra F no aparece en apellidos
# letra Y no aparece en apellidos
# letra D no aparece en apellidos
# letra Z aparece en apellidos
# letra Q no aparece en apellidos
# letra S no aparece en apellidos
# letra B no aparece en apellidos
# letra K no aparece en apellidos
# letra V no aparece en apellidos
# letra B no aparece en apellidos
# letra Y no aparece en apellidos
# letra O aparece en apellidos
# letra Z aparece en apellidos
# letra L no aparece en apellidos
# letra J no aparece en apellidos
# letra Z aparece en apellidos
# letra A aparece en apellidos
# letra L no aparece en apellidos
# letra J no aparece en apellidos
# letra Q no aparece en apellidos
# letra N aparece en apellidos
# letra Z aparece en apellidos
# letra E no aparece en apellidos
# letra J no aparece en apellidos
# letra D no aparece en apellidos
# letra O aparece en apellidos
# letra L no aparece en apellidos
# letra V no aparece en apellidos
# letra X no aparece en apellidos
# letra J no aparece en apellidos
# letra N aparece en apellidos
# letra H no aparece en apellidos
# letra A aparece en apellidos
# letra P aparece en apellidos
# letra A aparece en apellidos
# letra F no aparece en apellidos
# letra X no aparece en apellidos
# letra D no aparece en apellidos
# letra V no aparece en apellidos
# letra P aparece en apellidos
# letra F no aparece en apellidos
# letra P aparece en apellidos
# letra Y no aparece en apellidos
# letra W no aparece en apellidos
# letra P aparece en apellidos
# letra J no aparece en apellidos
# letra E no aparece en apellidos
# letra S no aparece en apellidos
# letra E no aparece en apellidos
# letra B no aparece en apellidos
# letra I no aparece en apellidos
# letra S no aparece en apellidos
# letra S no aparece en apellidos
# letra C no aparece en apellidos
# letra M no aparece en apellidos
# letra P aparece en apellidos
# letra R aparece en apellidos
# letra U no aparece en apellidos
# letra U no aparece en apellidos
# letra D no aparece en apellidos
# letra U no aparece en apellidos
# letra J no aparece en apellidos
# letra Z aparece en apellidos
# letra F no aparece en apellidos
# letra V no aparece en apellidos
# letra M no aparece en apellidos
# letra U no aparece en apellidos
# letra B no aparece en apellidos
# letra L no aparece en apellidos
# letra T aparece en apellidos
# letra D no aparece en apellidos
# letra T aparece en apellidos
# letra O aparece en apellidos
# letra T aparece en apellidos
# letra U no aparece en apellidos
# letra D no aparece en apellidos
# letra R aparece en apellidos
# letra G aparece en apellidos
# letra D no aparece en apellidos
# letra S no aparece en apellidos
# letra S no aparece en apellidos
# letra M no aparece en apellidos
# letra M no aparece en apellidos
# letra D no aparece en apellidos
# letra Z aparece en apellidos
# letra W no aparece en apellidos
# letra C no aparece en apellidos
# letra K no aparece en apellidos
# letra J no aparece en apellidos
# letra A aparece en apellidos
# letra D no aparece en apellidos
# letra C no aparece en apellidos
# letra V no aparece en apellidos
# letra S no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra B no aparece en apellidos
# letra N aparece en apellidos
# letra U no aparece en apellidos
# letra S no aparece en apellidos
# letra Q no aparece en apellidos
# letra F no aparece en apellidos
# letra F no aparece en apellidos
# letra X no aparece en apellidos
# letra A aparece en apellidos
# letra B no aparece en apellidos
# letra O aparece en apellidos
# letra J no aparece en apellidos
# letra H no aparece en apellidos
# letra M no aparece en apellidos
# letra I no aparece en apellidos
# letra W no aparece en apellidos
# letra N aparece en apellidos
# letra A aparece en apellidos
# letra S no aparece en apellidos
# letra P aparece en apellidos
# letra D no aparece en apellidos
# letra M no aparece en apellidos
# letra T aparece en apellidos
# letra L no aparece en apellidos
# letra X no aparece en apellidos
# letra G aparece en apellidos
# letra D no aparece en apellidos
# letra E no aparece en apellidos
# letra N aparece en apellidos
# letra G aparece en apellidos
# letra V no aparece en apellidos
# letra A aparece en apellidos
# letra E no aparece en apellidos
# letra K no aparece en apellidos
# letra M no aparece en apellidos
# letra L no aparece en apellidos
# letra T aparece en apellidos
# letra G aparece en apellidos
# letra J no aparece en apellidos
# letra F no aparece en apellidos
# letra W no aparece en apellidos
# letra A aparece en apellidos
# letra K no aparece en apellidos
# letra P aparece en apellidos
# letra M no aparece en apellidos
# letra O aparece en apellidos
# letra S no aparece en apellidos
# letra C no aparece en apellidos
# letra O aparece en apellidos
# letra Z aparece en apellidos
# letra X no aparece en apellidos
# letra W no aparece en apellidos
# letra B no aparece en apellidos
# letra C no aparece en apellidos
# letra F no aparece en apellidos
# letra I no aparece en apellidos
# letra B no aparece en apellidos
# letra P aparece en apellidos
# letra K no aparece en apellidos
# letra U no aparece en apellidos
# letra N aparece en apellidos
# letra Y no aparece en apellidos
# letra I no aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra Z aparece en apellidos
# letra F no aparece en apellidos
# letra M no aparece en apellidos
# letra D no aparece en apellidos
# letra N aparece en apellidos
# letra W no aparece en apellidos
# letra U no aparece en apellidos
# letra G aparece en apellidos
# letra G aparece en apellidos
# letra O aparece en apellidos
# letra U no aparece en apellidos
# letra K no aparece en apellidos
# letra W no aparece en apellidos
# letra K no aparece en apellidos
# letra E no aparece en apellidos
# letra V no aparece en apellidos
# letra R aparece en apellidos
# letra Z aparece en apellidos
# letra S no aparece en apellidos
# letra N aparece en apellidos
# letra X no aparece en apellidos
# letra I no aparece en apellidos
# letra Q no aparece en apellidos
# letra N aparece en apellidos
# letra C no aparece en apellidos
# letra Q no aparece en apellidos
# letra N aparece en apellidos
# letra K no aparece en apellidos
# letra S no aparece en apellidos
# letra E no aparece en apellidos
# letra D no aparece en apellidos
# letra X no aparece en apellidos
# letra C no aparece en apellidos
# letra J no aparece en apellidos
# letra B no aparece en apellidos
# letra D no aparece en apellidos
# letra R aparece en apellidos
# letra Z aparece en apellidos
# letra T aparece en apellidos
# letra K no aparece en apellidos
# letra G aparece en apellidos
# letra B no aparece en apellidos
# letra X no aparece en apellidos
# letra D no aparece en apellidos
# letra V no aparece en apellidos
# letra I no aparece en apellidos
# letra Z aparece en apellidos
# letra G aparece en apellidos
# letra J no aparece en apellidos
# letra V no aparece en apellidos
# letra V no aparece en apellidos
# letra J no aparece en apellidos
# letra C no aparece en apellidos
# letra U no aparece en apellidos
# letra A aparece en apellidos
# letra Y no aparece en apellidos
# letra T aparece en apellidos
# letra M no aparece en apellidos
# letra V no aparece en apellidos
# letra S no aparece en apellidos
# letra M no aparece en apellidos
# letra Y no aparece en apellidos
# letra Z aparece en apellidos
# letra M no aparece en apellidos
# letra M no aparece en apellidos
# letra J no aparece en apellidos
# letra K no aparece en apellidos
# letra B no aparece en apellidos
# letra K no aparece en apellidos
# letra Z aparece en apellidos
# letra F no aparece en apellidos
# letra N aparece en apellidos
# letra P aparece en apellidos
# letra C no aparece en apellidos
# letra Z aparece en apellidos
# letra S no aparece en apellidos
# letra W no aparece en apellidos
# letra P aparece en apellidos
# letra L no aparece en apellidos
# letra U no aparece en apellidos
# letra J no aparece en apellidos
# letra J no aparece en apellidos
# letra Z aparece en apellidos
# letra M no aparece en apellidos
# letra U no aparece en apellidos
# letra J no aparece en apellidos
# letra B no aparece en apellidos
# letra B no aparece en apellidos
# letra Q no aparece en apellidos
# letra N aparece en apellidos
# letra D no aparece en apellidos
# letra B no aparece en apellidos
# letra E no aparece en apellidos
# letra E no aparece en apellidos
# letra N aparece en apellidos
# letra T aparece en apellidos
# letra Y no aparece en apellidos
# letra Q no aparece en apellidos
# letra U no aparece en apellidos
# letra H no aparece en apellidos
# letra J no aparece en apellidos
# letra D no aparece en apellidos
# letra G aparece en apellidos
# letra V no aparece en apellidos
# letra U no aparece en apellidos
# letra U no aparece en apellidos
# letra Z aparece en apellidos
# letra G aparece en apellidos
# letra L no aparece en apellidos
# letra D no aparece en apellidos
# letra J no aparece en apellidos
# letra K no aparece en apellidos
# letra A aparece en apellidos
# letra L no aparece en apellidos
# letra X no aparece en apellidos
# letra Q no aparece en apellidos
# letra F no aparece en apellidos
# letra W no aparece en apellidos
# letra K no aparece en apellidos
# letra P aparece en apellidos
# letra V no aparece en apellidos
# letra L no aparece en apellidos
# letra A aparece en apellidos
# letra B no aparece en apellidos
# letra S no aparece en apellidos
# letra I no aparece en apellidos
# letra B no aparece en apellidos
# letra F no aparece en apellidos
# letra I no aparece en apellidos
# letra M no aparece en apellidos
# letra K no aparece en apellidos
# letra C no aparece en apellidos
# letra H no aparece en apellidos
# letra S no aparece en apellidos
# letra B no aparece en apellidos
# letra O aparece en apellidos
# letra M no aparece en apellidos
# letra I no aparece en apellidos
# letra W no aparece en apellidos
# letra U no aparece en apellidos
# letra Y no aparece en apellidos
# letra A aparece en apellidos
# letra P aparece en apellidos
# letra B no aparece en apellidos
# letra O aparece en apellidos
# letra Y no aparece en apellidos
# letra I no aparece en apellidos
# letra R aparece en apellidos
# letra N aparece en apellidos
# letra B no aparece en apellidos
# letra Q no aparece en apellidos
# letra H no aparece en apellidos
# letra J no aparece en apellidos
# letra W no aparece en apellidos
# letra Y no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra X no aparece en apellidos
# letra Z aparece en apellidos
# letra H no aparece en apellidos
# letra K no aparece en apellidos
# letra J no aparece en apellidos
# letra N aparece en apellidos
# letra W no aparece en apellidos
# letra U no aparece en apellidos
# letra Y no aparece en apellidos
# letra Q no aparece en apellidos
# letra V no aparece en apellidos
# letra D no aparece en apellidos
# letra V no aparece en apellidos
# letra R aparece en apellidos
# letra L no aparece en apellidos
# letra V no aparece en apellidos
# letra F no aparece en apellidos
# letra B no aparece en apellidos
# letra R aparece en apellidos
# letra J no aparece en apellidos
# letra V no aparece en apellidos
# letra Y no aparece en apellidos
# letra M no aparece en apellidos
# letra X no aparece en apellidos
# letra S no aparece en apellidos
# letra K no aparece en apellidos
# letra T aparece en apellidos
# letra H no aparece en apellidos
# letra L no aparece en apellidos
# letra J no aparece en apellidos
# letra D no aparece en apellidos
# letra B no aparece en apellidos
# letra N aparece en apellidos
# letra R aparece en apellidos
# letra M no aparece en apellidos
# letra Z aparece en apellidos
# letra R aparece en apellidos
# letra K no aparece en apellidos
# letra W no aparece en apellidos
# letra P aparece en apellidos
# letra E no aparece en apellidos
# letra E no aparece en apellidos
# letra Y no aparece en apellidos
# letra J no aparece en apellidos
# letra L no aparece en apellidos
# letra I no aparece en apellidos
# letra I no aparece en apellidos
# letra M no aparece en apellidos
# letra V no aparece en apellidos
# letra P aparece en apellidos
# letra H no aparece en apellidos
# letra R aparece en apellidos
# letra X no aparece en apellidos
# letra P aparece en apellidos
# letra V no aparece en apellidos
# letra N aparece en apellidos
# letra O aparece en apellidos
# letra G aparece en apellidos
# letra T aparece en apellidos
# letra R aparece en apellidos
# letra W no aparece en apellidos
# letra U no aparece en apellidos
# letra L no aparece en apellidos
# letra S no aparece en apellidos
# letra Q no aparece en apellidos
# letra M no aparece en apellidos
# letra F no aparece en apellidos
# letra V no aparece en apellidos
# letra V no aparece en apellidos
# letra F no aparece en apellidos
# letra M no aparece en apellidos
# letra I no aparece en apellidos
# letra P aparece en apellidos
# letra U no aparece en apellidos
# letra B no aparece en apellidos
# letra Q no aparece en apellidos
# letra H no aparece en apellidos
# letra X no aparece en apellidos
# letra M no aparece en apellidos
# letra J no aparece en apellidos
# letra V no aparece en apellidos
# letra B no aparece en apellidos
# letra T aparece en apellidos
# letra U no aparece en apellidos
# letra D no aparece en apellidos
# letra Y no aparece en apellidos
# letra O aparece en apellidos
# letra O aparece en apellidos
# letra K no aparece en apellidos
# letra W no aparece en apellidos
# letra A aparece en apellidos
# letra O aparece en apellidos
# letra S no aparece en apellidos
# letra T aparece en apellidos
# letra S no aparece en apellidos
# letra X no aparece en apellidos
# letra T aparece en apellidos
# letra U no aparece en apellidos
# letra Y no aparece en apellidos
# letra V no aparece en apellidos
# letra D no aparece en apellidos
# letra H no aparece en apellidos
# letra B no aparece en apellidos
# letra S no aparece en apellidos
# letra O aparece en apellidos
# letra O aparece en apellidos
# letra J no aparece en apellidos
# letra P aparece en apellidos
# letra O aparece en apellidos
# letra I no aparece en apellidos
# letra Z aparece en apellidos
# letra W no aparece en apellidos
# letra F no aparece en apellidos
# letra H no aparece en apellidos
# letra D no aparece en apellidos
# letra B no aparece en apellidos
# letra K no aparece en apellidos
# letra T aparece en apellidos
# letra N aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra V no aparece en apellidos
# letra F no aparece en apellidos
# letra Y no aparece en apellidos
# letra R aparece en apellidos
# letra Q no aparece en apellidos
# letra M no aparece en apellidos
# letra P aparece en apellidos
# letra K no aparece en apellidos
# letra Y no aparece en apellidos
# letra D no aparece en apellidos
# letra R aparece en apellidos
# letra B no aparece en apellidos
# letra T aparece en apellidos
# letra W no aparece en apellidos
# letra K no aparece en apellidos
# letra G aparece en apellidos
# letra P aparece en apellidos
# letra C no aparece en apellidos
# letra S no aparece en apellidos
# letra J no aparece en apellidos
# letra P aparece en apellidos
# letra X no aparece en apellidos
# letra L no aparece en apellidos
# letra B no aparece en apellidos
# letra E no aparece en apellidos
# letra H no aparece en apellidos
# letra T aparece en apellidos
# letra P aparece en apellidos
# letra S no aparece en apellidos
# letra N aparece en apellidos
# letra P aparece en apellidos
# letra D no aparece en apellidos
# letra T aparece en apellidos
# letra B no aparece en apellidos
# letra Y no aparece en apellidos
# letra J no aparece en apellidos
# letra A aparece en apellidos
# letra J no aparece en apellidos
# letra S no aparece en apellidos
# letra E no aparece en apellidos
# letra I no aparece en apellidos
# letra H no aparece en apellidos
# letra G aparece en apellidos
# letra Z aparece en apellidos
# letra Y no aparece en apellidos
# letra H no aparece en apellidos
# letra B no aparece en apellidos
# letra A aparece en apellidos
# letra B no aparece en apellidos
# letra M no aparece en apellidos
# letra P aparece en apellidos
# letra W no aparece en apellidos
# letra S no aparece en apellidos
# letra J no aparece en apellidos
# letra N aparece en apellidos
# letra I no aparece en apellidos
# letra P aparece en apellidos
# letra G aparece en apellidos
# letra E no aparece en apellidos
# letra Q no aparece en apellidos
# letra R aparece en apellidos
# letra K no aparece en apellidos
# letra Y no aparece en apellidos
# letra P aparece en apellidos
# letra G aparece en apellidos
# letra G aparece en apellidos
# letra P aparece en apellidos
# letra L no aparece en apellidos
# letra J no aparece en apellidos
# letra Y no aparece en apellidos
# letra D no aparece en apellidos
# letra M no aparece en apellidos
# letra G aparece en apellidos
# letra U no aparece en apellidos
# letra I no aparece en apellidos
# letra I no aparece en apellidos
# letra B no aparece en apellidos
# letra Q no aparece en apellidos
# letra J no aparece en apellidos
# letra B no aparece en apellidos
# letra A aparece en apellidos
# letra S no aparece en apellidos
# letra U no aparece en apellidos
# letra E no aparece en apellidos
# letra R aparece en apellidos
# letra L no aparece en apellidos
# letra N aparece en apellidos
# letra B no aparece en apellidos
# letra K no aparece en apellidos
# letra X no aparece en apellidos
# letra P aparece en apellidos
# letra I no aparece en apellidos
# letra G aparece en apellidos
# letra A aparece en apellidos
# letra K no aparece en apellidos
# letra B no aparece en apellidos
# letra Y no aparece en apellidos
# letra N aparece en apellidos
# letra Y no aparece en apellidos
# letra O aparece en apellidos
# letra E no aparece en apellidos
# letra U no aparece en apellidos
# letra U no aparece en apellidos
# letra X no aparece en apellidos
# letra D no aparece en apellidos
# letra D no aparece en apellidos
# letra S no aparece en apellidos
# letra K no aparece en apellidos
# letra I no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra R aparece en apellidos
# letra P aparece en apellidos
# letra Y no aparece en apellidos
# letra V no aparece en apellidos
# letra M no aparece en apellidos
# letra K no aparece en apellidos
# letra F no aparece en apellidos
# letra X no aparece en apellidos
# letra H no aparece en apellidos
# letra L no aparece en apellidos
# letra H no aparece en apellidos
# letra J no aparece en apellidos
# letra R aparece en apellidos
# letra G aparece en apellidos
# letra F no aparece en apellidos
# letra D no aparece en apellidos
# letra K no aparece en apellidos
# letra L no aparece en apellidos
# letra P aparece en apellidos
# letra A aparece en apellidos
# letra I no aparece en apellidos
# letra X no aparece en apellidos
# letra M no aparece en apellidos
# letra R aparece en apellidos
# letra Y no aparece en apellidos
# letra I no aparece en apellidos
# letra T aparece en apellidos
# letra F no aparece en apellidos
# letra R aparece en apellidos
# letra Z aparece en apellidos
# letra K no aparece en apellidos
# letra R aparece en apellidos
# letra E no aparece en apellidos
# letra Y no aparece en apellidos
# letra M no aparece en apellidos
# letra G aparece en apellidos
# letra X no aparece en apellidos
# letra Z aparece en apellidos
# letra T aparece en apellidos
# letra A aparece en apellidos
# letra A aparece en apellidos
# letra P aparece en apellidos
# letra H no aparece en apellidos
# letra T aparece en apellidos
# letra M no aparece en apellidos
# letra K no aparece en apellidos
# letra T aparece en apellidos
# letra J no aparece en apellidos
# letra I no aparece en apellidos
# letra J no aparece en apellidos
# letra C no aparece en apellidos
# letra Y no aparece en apellidos
# letra L no aparece en apellidos
# letra B no aparece en apellidos
# letra P aparece en apellidos
# letra Q no aparece en apellidos
# letra D no aparece en apellidos
# letra E no aparece en apellidos
# letra D no aparece en apellidos
# letra P aparece en apellidos
# letra O aparece en apellidos
# letra H no aparece en apellidos
# letra N aparece en apellidos
# letra A aparece en apellidos
# letra T aparece en apellidos
# letra C no aparece en apellidos
# letra L no aparece en apellidos
# letra P aparece en apellidos
# letra P aparece en apellidos
# letra J no aparece en apellidos
# letra D no aparece en apellidos
# letra I no aparece en apellidos
# letra H no aparece en apellidos
# letra T aparece en apellidos
# letra Y no aparece en apellidos
# letra C no aparece en apellidos
# letra S no aparece en apellidos
# letra L no aparece en apellidos
# letra N aparece en apellidos
# letra G aparece en apellidos
# letra Q no aparece en apellidos
# letra I no aparece en apellidos
# letra V no aparece en apellidos
# letra R aparece en apellidos
# letra N aparece en apellidos
# letra C no aparece en apellidos
# letra T aparece en apellidos
# letra R aparece en apellidos
# letra Z aparece en apellidos
# letra B no aparece en apellidos
# letra T aparece en apellidos
# letra R aparece en apellidos
# letra J no aparece en apellidos
# letra M no aparece en apellidos
# letra X no aparece en apellidos
# letra S no aparece en apellidos
# letra S no aparece en apellidos
# letra G aparece en apellidos
# letra B no aparece en apellidos
# letra M no aparece en apellidos
# letra S no aparece en apellidos
# letra M no aparece en apellidos
# letra L no aparece en apellidos
# letra G aparece en apellidos
# letra C no aparece en apellidos
# letra S no aparece en apellidos
# letra C no aparece en apellidos
# letra R aparece en apellidos
# letra G aparece en apellidos
# letra C no aparece en apellidos
# letra I no aparece en apellidos
# letra Y no aparece en apellidos
# letra C no aparece en apellidos
# letra Y no aparece en apellidos
# letra K no aparece en apellidos
# letra I no aparece en apellidos
# letra E no aparece en apellidos
# letra O aparece en apellidos
# letra M no aparece en apellidos
# letra Q no aparece en apellidos
# letra Z aparece en apellidos
# letra H no aparece en apellidos
# letra Z aparece en apellidos
# letra H no aparece en apellidos
# letra O aparece en apellidos
# letra U no aparece en apellidos
# letra W no aparece en apellidos
# letra L no aparece en apellidos
# letra J no aparece en apellidos
# letra L no aparece en apellidos
# letra O aparece en apellidos
# letra K no aparece en apellidos
# letra J no aparece en apellidos
# letra K no aparece en apellidos
# letra T aparece en apellidos
# letra G aparece en apellidos
# letra M no aparece en apellidos
# letra J no aparece en apellidos
# letra V no aparece en apellidos
# letra T aparece en apellidos
# letra Y no aparece en apellidos
# letra C no aparece en apellidos
# letra A aparece en apellidos
# letra R aparece en apellidos
# letra M no aparece en apellidos
# letra U no aparece en apellidos
# letra Q no aparece en apellidos
# letra X no aparece en apellidos
# letra C no aparece en apellidos
# letra Y no aparece en apellidos
# letra L no aparece en apellidos
# letra M no aparece en apellidos
# letra S no aparece en apellidos
# letra I no aparece en apellidos
# letra J no aparece en apellidos
# letra E no aparece en apellidos
# letra M no aparece en apellidos
# letra L no aparece en apellidos
# letra T aparece en apellidos
# letra X no aparece en apellidos
# letra X no aparece en apellidos
# letra V no aparece en apellidos
# letra D no aparece en apellidos
# letra X no aparece en apellidos
# letra S no aparece en apellidos
# letra B no aparece en apellidos
# letra E no aparece en apellidos
# letra S no aparece en apellidos
# letra K no aparece en apellidos
# letra P aparece en apellidos
# letra Z aparece en apellidos
# letra R aparece en apellidos
# letra S no aparece en apellidos
# letra F no aparece en apellidos
# letra L no aparece en apellidos
# letra N aparece en apellidos
# letra N aparece en apellidos
# letra N aparece en apellidos
# letra D no aparece en apellidos
# letra M no aparece en apellidos
# letra Y no aparece en apellidos
# letra R aparece en apellidos
# letra D no aparece en apellidos
# letra E no aparece en apellidos
# letra R aparece en apellidos
# letra M no aparece en apellidos
# letra I no aparece en apellidos
# letra F no aparece en apellidos
# letra P aparece en apellidos
# letra S no aparece en apellidos
# letra X no aparece en apellidos
# letra T aparece en apellidos
# letra R aparece en apellidos
# letra O aparece en apellidos
# letra A aparece en apellidos
# letra P aparece en apellidos
# letra X no aparece en apellidos
# letra M no aparece en apellidos
# letra U no aparece en apellidos
# letra B no aparece en apellidos
# letra Z aparece en apellidos
# letra G aparece en apellidos
# letra P aparece en apellidos
# letra S no aparece en apellidos
# letra M no aparece en apellidos
# letra E no aparece en apellidos
# letra K no aparece en apellidos
# letra T aparece en apellidos
# letra A aparece en apellidos
# letra S no aparece en apellidos
# letra R aparece en apellidos
# letra D no aparece en apellidos
# letra H no aparece en apellidos
# letra G aparece en apellidos
# letra E no aparece en apellidos
# letra O aparece en apellidos
# letra J no aparece en apellidos
# letra C no aparece en apellidos
# letra I no aparece en apellidos
# letra D no aparece en apellidos
# letra F no aparece en apellidos
# letra U no aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra W no aparece en apellidos
# letra R aparece en apellidos
# letra J no aparece en apellidos
# letra Z aparece en apellidos
# letra C no aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra T aparece en apellidos
# letra E no aparece en apellidos
# letra E no aparece en apellidos
# letra P aparece en apellidos
# letra F no aparece en apellidos
# letra C no aparece en apellidos
# letra S no aparece en apellidos
# letra S no aparece en apellidos
# letra N aparece en apellidos
# letra T aparece en apellidos
# letra A aparece en apellidos
# letra X no aparece en apellidos
# letra W no aparece en apellidos
# letra V no aparece en apellidos
# letra F no aparece en apellidos
# letra D no aparece en apellidos
# letra Q no aparece en apellidos
# letra H no aparece en apellidos
# letra O aparece en apellidos
# letra V no aparece en apellidos
# letra T aparece en apellidos
# letra U no aparece en apellidos
# letra Y no aparece en apellidos
# letra G aparece en apellidos
# letra H no aparece en apellidos
# letra U no aparece en apellidos
# letra I no aparece en apellidos
# letra L no aparece en apellidos
# letra P aparece en apellidos
# letra L no aparece en apellidos
# letra N aparece en apellidos
# letra W no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra G aparece en apellidos
# letra Y no aparece en apellidos
# letra L no aparece en apellidos
# letra M no aparece en apellidos
# letra O aparece en apellidos
# letra G aparece en apellidos
# letra Y no aparece en apellidos
# letra M no aparece en apellidos
# letra A aparece en apellidos
# letra P aparece en apellidos
# letra U no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra P aparece en apellidos
# letra H no aparece en apellidos
# letra A aparece en apellidos
# letra F no aparece en apellidos
# letra G aparece en apellidos
# letra X no aparece en apellidos
# letra S no aparece en apellidos
# letra K no aparece en apellidos
# letra D no aparece en apellidos
# letra J no aparece en apellidos
# letra T aparece en apellidos
# letra P aparece en apellidos
# letra K no aparece en apellidos
# letra A aparece en apellidos
# letra A aparece en apellidos
# letra C no aparece en apellidos
# letra M no aparece en apellidos
# letra V no aparece en apellidos
# letra M no aparece en apellidos
# letra J no aparece en apellidos
# letra O aparece en apellidos
# letra S no aparece en apellidos
# letra N aparece en apellidos
# letra L no aparece en apellidos
# letra V no aparece en apellidos
# letra H no aparece en apellidos
# letra Z aparece en apellidos
# letra J no aparece en apellidos
# letra K no aparece en apellidos
# letra X no aparece en apellidos
# letra C no aparece en apellidos
# letra D no aparece en apellidos
# letra E no aparece en apellidos
# letra M no aparece en apellidos
# letra A aparece en apellidos
# letra M no aparece en apellidos
# letra C no aparece en apellidos
# letra J no aparece en apellidos
# letra J no aparece en apellidos
# letra L no aparece en apellidos
# letra Q no aparece en apellidos
# letra M no aparece en apellidos
# letra Z aparece en apellidos
# letra Q no aparece en apellidos
# letra N aparece en apellidos
# letra V no aparece en apellidos
# letra B no aparece en apellidos
# letra K no aparece en apellidos
# letra Q no aparece en apellidos
# letra A aparece en apellidos
# letra R aparece en apellidos
# letra I no aparece en apellidos
# letra M no aparece en apellidos
# letra H no aparece en apellidos
# letra D no aparece en apellidos
# letra D no aparece en apellidos
# letra H no aparece en apellidos
# letra R aparece en apellidos
# letra Z aparece en apellidos
# letra Q no aparece en apellidos
# letra B no aparece en apellidos
# letra G aparece en apellidos
# letra B no aparece en apellidos
# letra C no aparece en apellidos
# letra K no aparece en apellidos
# letra C no aparece en apellidos
# letra W no aparece en apellidos
# letra Q no aparece en apellidos
# letra U no aparece en apellidos
# letra X no aparece en apellidos
# letra D no aparece en apellidos
# letra F no aparece en apellidos
# letra Z aparece en apellidos
# letra K no aparece en apellidos
# letra S no aparece en apellidos
# letra O aparece en apellidos
# letra X no aparece en apellidos
# letra N aparece en apellidos
# letra Q no aparece en apellidos
# letra J no aparece en apellidos
# letra J no aparece en apellidos
# letra H no aparece en apellidos
# letra O aparece en apellidos
# letra B no aparece en apellidos
# letra P aparece en apellidos
# letra N aparece en apellidos
# letra E no aparece en apellidos
# letra I no aparece en apellidos
# letra L no aparece en apellidos
# letra H no aparece en apellidos
# letra H no aparece en apellidos
# letra M no aparece en apellidos
# letra H no aparece en apellidos
# letra X no aparece en apellidos
# letra U no aparece en apellidos
# letra I no aparece en apellidos
# letra X no aparece en apellidos
# letra C no aparece en apellidos
# letra B no aparece en apellidos
# letra D no aparece en apellidos
# letra V no aparece en apellidos
# letra K no aparece en apellidos
# letra K no aparece en apellidos
# letra B no aparece en apellidos
# letra Q no aparece en apellidos
# letra T aparece en apellidos
# letra H no aparece en apellidos
# letra L no aparece en apellidos
# letra W no aparece en apellidos
# letra R aparece en apellidos
# letra Y no aparece en apellidos
# letra A aparece en apellidos
# letra U no aparece en apellidos
# letra Z aparece en apellidos
# letra D no aparece en apellidos
# letra J no aparece en apellidos
# letra X no aparece en apellidos
# letra S no aparece en apellidos
# letra O aparece en apellidos
# letra V no aparece en apellidos
# letra C no aparece en apellidos
# letra H no aparece en apellidos
# letra R aparece en apellidos
# letra M no aparece en apellidos
# letra T aparece en apellidos
# letra Y no aparece en apellidos
# letra Y no aparece en apellidos
# letra J no aparece en apellidos
# letra F no aparece en apellidos
# letra J no aparece en apellidos
# letra C no aparece en apellidos
# letra G aparece en apellidos
# letra Q no aparece en apellidos
# letra P aparece en apellidos
# letra Q no aparece en apellidos
# letra D no aparece en apellidos
# letra V no aparece en apellidos
# letra G aparece en apellidos
# letra Y no aparece en apellidos
# letra L no aparece en apellidos
# letra N aparece en apellidos
# letra V no aparece en apellidos
# letra C no aparece en apellidos
# letra I no aparece en apellidos
# letra Y no aparece en apellidos
# letra O aparece en apellidos
# letra M no aparece en apellidos
# letra E no aparece en apellidos
# letra I no aparece en apellidos
# letra C no aparece en apellidos
# letra E no aparece en apellidos
# letra I no aparece en apellidos
# letra E no aparece en apellidos
# letra X no aparece en apellidos
# letra X no aparece en apellidos
# letra G aparece en apellidos
# letra E no aparece en apellidos
# letra J no aparece en apellidos
# letra D no aparece en apellidos
# letra S no aparece en apellidos
# letra Z aparece en apellidos
# letra W no aparece en apellidos
# letra M no aparece en apellidos
# letra L no aparece en apellidos
# letra R aparece en apellidos
# letra H no aparece en apellidos
# letra D no aparece en apellidos
# letra S no aparece en apellidos
# letra Y no aparece en apellidos
# letra N aparece en apellidos
# letra Y no aparece en apellidos
# letra R aparece en apellidos
# letra D no aparece en apellidos
# letra O aparece en apellidos
# letra G aparece en apellidos
# letra H no aparece en apellidos
# letra Y no aparece en apellidos
# letra M no aparece en apellidos
# letra P aparece en apellidos
# letra H no aparece en apellidos
# letra V no aparece en apellidos
# letra B no aparece en apellidos
# letra X no aparece en apellidos
# letra O aparece en apellidos
# letra K no aparece en apellidos
# letra G aparece en apellidos
# letra T aparece en apellidos
# letra K no aparece en apellidos
# letra H no aparece en apellidos
# letra G aparece en apellidos
# letra B no aparece en apellidos
# letra V no aparece en apellidos
# letra T aparece en apellidos
# letra N aparece en apellidos
# letra U no aparece en apellidos
# letra Z aparece en apellidos
# letra K no aparece en apellidos
# letra H no aparece en apellidos
# letra I no aparece en apellidos
# letra A aparece en apellidos
# letra H no aparece en apellidos
# letra G aparece en apellidos
# letra O aparece en apellidos
# letra E no aparece en apellidos
# letra X no aparece en apellidos
# letra J no aparece en apellidos
# letra O aparece en apellidos
# letra X no aparece en apellidos
# letra V no aparece en apellidos
# letra C no aparece en apellidos
# letra M no aparece en apellidos
# letra Q no aparece en apellidos
# letra K no aparece en apellidos
# letra W no aparece en apellidos
# letra R aparece en apellidos
# letra G aparece en apellidos
# letra S no aparece en apellidos
# letra O aparece en apellidos
# letra Y no aparece en apellidos
# letra P aparece en apellidos
# letra T aparece en apellidos
# letra R aparece en apellidos
# letra H no aparece en apellidos
# letra E no aparece en apellidos
# letra B no aparece en apellidos
# letra F no aparece en apellidos
# letra N aparece en apellidos
# letra H no aparece en apellidos
# letra H no aparece en apellidos
# letra L no aparece en apellidos
# letra Q no aparece en apellidos
# letra I no aparece en apellidos
# letra F no aparece en apellidos
# letra D no aparece en apellidos
# letra B no aparece en apellidos
# letra D no aparece en apellidos
# letra A aparece en apellidos
# letra W no aparece en apellidos
# letra D no aparece en apellidos
# letra D no aparece en apellidos
# letra T aparece en apellidos
# letra W no aparece en apellidos
# letra E no aparece en apellidos
# letra Z aparece en apellidos
# letra Y no aparece en apellidos
# letra U no aparece en apellidos
# letra J no aparece en apellidos
# letra E no aparece en apellidos
# letra W no aparece en apellidos
# letra Y no aparece en apellidos
# letra I no aparece en apellidos
# letra J no aparece en apellidos
# letra I no aparece en apellidos
# letra P aparece en apellidos
# letra N aparece en apellidos
# letra H no aparece en apellidos
# letra P aparece en apellidos
# letra Y no aparece en apellidos
# letra E no aparece en apellidos
# letra S no aparece en apellidos
# letra T aparece en apellidos
# letra M no aparece en apellidos
# letra L no aparece en apellidos
# letra V no aparece en apellidos
# letra B no aparece en apellidos
# letra V no aparece en apellidos
# letra S no aparece en apellidos
# letra Q no aparece en apellidos
# letra S no aparece en apellidos
# letra O aparece en apellidos
# letra E no aparece en apellidos
# letra A aparece en apellidos
# letra T aparece en apellidos
# letra G aparece en apellidos
# letra R aparece en apellidos
# letra H no aparece en apellidos
# letra M no aparece en apellidos
# letra D no aparece en apellidos
# letra X no aparece en apellidos
# letra C no aparece en apellidos
# letra S no aparece en apellidos
# letra P aparece en apellidos
# letra P aparece en apellidos
# letra J no aparece en apellidos
# letra R aparece en apellidos
# letra E no aparece en apellidos
# letra J no aparece en apellidos
# letra Q no aparece en apellidos
# letra V no aparece en apellidos
# letra O aparece en apellidos
# letra G aparece en apellidos
# letra P aparece en apellidos
# letra I no aparece en apellidos
# letra G aparece en apellidos
# letra D no aparece en apellidos
# letra U no aparece en apellidos
# letra D no aparece en apellidos
# letra A aparece en apellidos
# letra U no aparece en apellidos
# letra V no aparece en apellidos
# letra D no aparece en apellidos
# letra A aparece en apellidos
# letra U no aparece en apellidos
# letra M no aparece en apellidos
# letra X no aparece en apellidos
# letra P aparece en apellidos
# letra Z aparece en apellidos
# letra J no aparece en apellidos
# letra X no aparece en apellidos
# letra G aparece en apellidos
# letra C no aparece en apellidos
# letra R aparece en apellidos
# letra B no aparece en apellidos
# letra T aparece en apellidos
# letra O aparece en apellidos
# letra G aparece en apellidos
# letra N aparece en apellidos
# letra K no aparece en apellidos
# letra N aparece en apellidos
# letra S no aparece en apellidos
# letra K no aparece en apellidos
# letra A aparece en apellidos
# letra I no aparece en apellidos
# letra I no aparece en apellidos
# letra J no aparece en apellidos
# letra O aparece en apellidos
# letra C no aparece en apellidos
# letra L no aparece en apellidos
# letra T aparece en apellidos
# letra K no aparece en apellidos
# letra P aparece en apellidos
# letra U no aparece en apellidos
# letra P aparece en apellidos
# letra T aparece en apellidos
# letra C no aparece en apellidos
# letra N aparece en apellidos
# letra H no aparece en apellidos
# letra K no aparece en apellidos
# letra F no aparece en apellidos
# letra C no aparece en apellidos
# letra F no aparece en apellidos
# letra L no aparece en apellidos
# letra Y no aparece en apellidos
# letra S no aparece en apellidos
# letra U no aparece en apellidos
# letra N aparece en apellidos
# letra Z aparece en apellidos
# letra O aparece en apellidos
# letra P aparece en apellidos
# letra J no aparece en apellidos
# letra O aparece en apellidos
# letra Z aparece en apellidos
# letra X no aparece en apellidos
# letra H no aparece en apellidos
# letra X no aparece en apellidos
# letra H no aparece en apellidos
# letra K no aparece en apellidos
# letra D no aparece en apellidos
# letra T aparece en apellidos
# letra A aparece en apellidos
# letra H no aparece en apellidos
# letra Q no aparece en apellidos
# letra I no aparece en apellidos
# letra P aparece en apellidos
# letra F no aparece en apellidos
# letra K no aparece en apellidos
# letra H no aparece en apellidos
# letra E no aparece en apellidos
# letra A aparece en apellidos
# letra C no aparece en apellidos
# letra H no aparece en apellidos
# letra I no aparece en apellidos
# letra J no aparece en apellidos
# letra Y no aparece en apellidos
# letra G aparece en apellidos
# letra X no aparece en apellidos
# letra T aparece en apellidos
# letra D no aparece en apellidos
# letra Q no aparece en apellidos
# letra Y no aparece en apellidos
# letra O aparece en apellidos
# letra B no aparece en apellidos
# letra E no aparece en apellidos
# letra Z aparece en apellidos
# letra X no aparece en apellidos
# letra G aparece en apellidos
# letra M no aparece en apellidos
# letra U no aparece en apellidos
# letra X no aparece en apellidos
# letra W no aparece en apellidos
# letra M no aparece en apellidos
# letra T aparece en apellidos
# letra B no aparece en apellidos
# letra J no aparece en apellidos
# letra I no aparece en apellidos
# letra L no aparece en apellidos
# letra F no aparece en apellidos
# letra L no aparece en apellidos
# letra N aparece en apellidos
# letra J no aparece en apellidos
# letra E no aparece en apellidos
# letra B no aparece en apellidos
# letra G aparece en apellidos
# letra Y no aparece en apellidos
# letra H no aparece en apellidos
# letra B no aparece en apellidos
# letra Y no aparece en apellidos
# letra A aparece en apellidos
# letra R aparece en apellidos
# letra R aparece en apellidos
# letra H no aparece en apellidos
# letra A aparece en apellidos
# letra D no aparece en apellidos
# letra P aparece en apellidos
# letra A aparece en apellidos
# letra E no aparece en apellidos
# letra Y no aparece en apellidos
# letra V no aparece en apellidos
# letra Q no aparece en apellidos
# letra F no aparece en apellidos
# letra G aparece en apellidos
# letra N aparece en apellidos
# letra Q no aparece en apellidos
# letra X no aparece en apellidos
# letra K no aparece en apellidos
# letra I no aparece en apellidos
# letra V no aparece en apellidos
# letra K no aparece en apellidos
# letra V no aparece en apellidos
# letra L no aparece en apellidos
# letra W no aparece en apellidos
# letra D no aparece en apellidos
# letra U no aparece en apellidos
# letra S no aparece en apellidos
# letra D no aparece en apellidos
# letra V no aparece en apellidos
# letra Z aparece en apellidos
# letra E no aparece en apellidos
# letra Y no aparece en apellidos
# letra T aparece en apellidos
# letra M no aparece en apellidos
# letra L no aparece en apellidos
# letra S no aparece en apellidos
# letra J no aparece en apellidos
# letra B no aparece en apellidos
# letra Z aparece en apellidos
# letra S no aparece en apellidos
# letra A aparece en apellidos
# letra R aparece en apellidos
# letra Y no aparece en apellidos
# letra U no aparece en apellidos
# letra Y no aparece en apellidos
# letra Z aparece en apellidos
# letra X no aparece en apellidos
# letra R aparece en apellidos
# letra S no aparece en apellidos
# letra Q no aparece en apellidos
# letra D no aparece en apellidos
# letra C no aparece en apellidos
# letra P aparece en apellidos
# letra G aparece en apellidos
# letra Z aparece en apellidos
# letra N aparece en apellidos
# letra M no aparece en apellidos
# letra A aparece en apellidos
# letra N aparece en apellidos
# letra Z aparece en apellidos
# letra T aparece en apellidos
# letra I no aparece en apellidos
# letra N aparece en apellidos
# letra D no aparece en apellidos
# letra X no aparece en apellidos
# letra Z aparece en apellidos
# letra N aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra A aparece en apellidos
# letra G aparece en apellidos
# letra W no aparece en apellidos
# letra B no aparece en apellidos
# letra Q no aparece en apellidos
# letra O aparece en apellidos
# letra N aparece en apellidos
# letra I no aparece en apellidos
# letra N aparece en apellidos
# letra U no aparece en apellidos
# letra Z aparece en apellidos
# letra K no aparece en apellidos
# letra C no aparece en apellidos
# letra N aparece en apellidos
# letra K no aparece en apellidos
# letra C no aparece en apellidos
# letra R aparece en apellidos
# letra O aparece en apellidos
# letra Q no aparece en apellidos
# letra I no aparece en apellidos
# letra W no aparece en apellidos
# letra X no aparece en apellidos
# letra T aparece en apellidos
# letra R aparece en apellidos
# letra J no aparece en apellidos
# letra K no aparece en apellidos
# letra J no aparece en apellidos
# letra E no aparece en apellidos
# letra A aparece en apellidos
# letra C no aparece en apellidos
# letra X no aparece en apellidos
# letra L no aparece en apellidos
# letra S no aparece en apellidos
# letra N aparece en apellidos
# letra F no aparece en apellidos
# letra S no aparece en apellidos
# letra K no aparece en apellidos
# letra O aparece en apellidos
# letra J no aparece en apellidos
# ...
# letra M no aparece en apellidos
# letra K no aparece en apellidos
# letra I no aparece en apellidos
# letra V no aparece en apellidos
# letra J no aparece en apellidos
# letra R aparece en apellidos
# letra U no aparece en apellidos
# letra Z aparece en apellidos
# letra W no aparece en apellidos
# letra W no aparece en apellidos
# letra Q no aparece en apellidos
# letra P aparece en apellidos
# letra M no aparece en apellidos
# letra E no aparece en apellidos
# letra U no aparece en apellidos
# letra G aparece en apellidos
# letra Z aparece en apellidos
# letra L no aparece en apellidos
# letra F no aparece en apellidos
# letra M no aparece en apellidos
# letra J no aparece en apellidos
# letra D no aparece en apellidos
# letra X no aparece en apellidos
# letra U no aparece en apellidos
# letra V no aparece en apellidos
# letra Q no aparece en apellidos
# letra J no aparece en apellidos
# letra S no aparece en apellidos
# letra B no aparece en apellidos
# letra N aparece en apellidos
# letra F no aparece en apellidos
# letra Z aparece en apellidos
# letra S no aparece en apellidos
# letra P aparece en apellidos
# letra H no aparece en apellidos
# letra O aparece en apellidos
# letra H no aparece en apellidos
# letra Q no aparece en apellidos
# letra L no aparece en apellidos
# letra X no aparece en apellidos
# letra F no aparece en apellidos
# letra Q no aparece en apellidos
# letra L no aparece en apellidos
# letra P aparece en apellidos
# letra Z aparece en apellidos
# letra J no aparece en apellidos
# letra D no aparece en apellidos
# letra K no aparece en apellidos
# letra T aparece en apellidos
# letra C no aparece en apellidos
# letra U no aparece en apellidos
# letra Z aparece en apellidos
# letra F no aparece en apellidos
# letra M no aparece en apellidos
# letra Y no aparece en apellidos
# letra Q no aparece en apellidos
# letra O aparece en apellidos
# letra X no aparece en apellidos
# letra B no aparece en apellidos
# letra O aparece en apellidos
# letra U no aparece en apellidos
# letra U no aparece en apellidos
# letra Y no aparece en apellidos
# letra B no aparece en apellidos
# letra D no aparece en apellidos
# letra Q no aparece en apellidos
# letra Y no aparece en apellidos
# letra G aparece en apellidos
# letra E no aparece en apellidos
# letra N aparece en apellidos
# letra V no aparece en apellidos
# letra U no aparece en apellidos
# letra K no aparece en apellidos
# letra V no aparece en apellidos
# letra L no aparece en apellidos
# letra F no aparece en apellidos
# letra Z aparece en apellidos
# letra I no aparece en apellidos
# letra D no aparece en apellidos
# letra X no aparece en apellidos
# letra X no aparece en apellidos
# letra G aparece en apellidos
# letra Y no aparece en apellidos
# letra E no aparece en apellidos
# letra D no aparece en apellidos
# letra X no aparece en apellidos
# letra N aparece en apellidos
# letra P aparece en apellidos
# letra F no aparece en apellidos
# letra F no aparece en apellidos
# letra R aparece en apellidos
# letra P aparece en apellidos
# letra A aparece en apellidos
# letra X no aparece en apellidos
# letra A aparece en apellidos
# letra L no aparece en apellidos
# letra Y no aparece en apellidos
# letra P aparece en apellidos
# letra W no aparece en apellidos
# letra B no aparece en apellidos
# letra Y no aparece en apellidos
# letra K no aparece en apellidos
# letra I no aparece en apellidos
# letra S no aparece en apellidos
# letra I no aparece en apellidos
# letra J no aparece en apellidos
# letra X no aparece en apellidos
# letra H no aparece en apellidos
# letra G aparece en apellidos
# letra Y no aparece en apellidos
# letra Y no aparece en apellidos
# letra N aparece en apellidos
# letra D no aparece en apellidos
# letra Q no aparece en apellidos
# letra T aparece en apellidos
# letra Q no aparece en apellidos
# letra O aparece en apellidos
# letra A aparece en apellidos
# letra O aparece en apellidos
# letra E no aparece en apellidos
# letra C no aparece en apellidos
# letra A aparece en apellidos
# letra C no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra F no aparece en apellidos
# letra D no aparece en apellidos
# letra L no aparece en apellidos
# letra F no aparece en apellidos
# letra U no aparece en apellidos
# letra P aparece en apellidos
# letra C no aparece en apellidos
# letra Q no aparece en apellidos
# letra J no aparece en apellidos
# letra K no aparece en apellidos
# letra P aparece en apellidos
# letra V no aparece en apellidos
# letra G aparece en apellidos
# letra E no aparece en apellidos
# letra T aparece en apellidos
# letra N aparece en apellidos
# letra Z aparece en apellidos
# letra U no aparece en apellidos
# letra Y no aparece en apellidos
# letra Z aparece en apellidos
# letra Y no aparece en apellidos
# letra H no aparece en apellidos
# letra B no aparece en apellidos
# letra Z aparece en apellidos
# letra J no aparece en apellidos
# letra Z aparece en apellidos
# letra X no aparece en apellidos
# letra R aparece en apellidos
# letra T aparece en apellidos
# letra B no aparece en apellidos
# letra T aparece en apellidos
# letra Z aparece en apellidos
# letra Z aparece en apellidos
# letra Z aparece en apellidos
# letra H no aparece en apellidos
# letra B no aparece en apellidos
# letra J no aparece en apellidos
# letra R aparece en apellidos
# letra O aparece en apellidos
# letra F no aparece en apellidos
# letra M no aparece en apellidos
# letra L no aparece en apellidos
# letra N aparece en apellidos
# letra T aparece en apellidos
# letra L no aparece en apellidos
# letra O aparece en apellidos
# letra M no aparece en apellidos
# letra N aparece en apellidos
# letra H no aparece en apellidos
# letra V no aparece en apellidos
# letra A aparece en apellidos
# letra C no aparece en apellidos
# letra W no aparece en apellidos
# letra P aparece en apellidos
# letra B no aparece en apellidos
# letra Y no aparece en apellidos
# letra O aparece en apellidos
# letra T aparece en apellidos
# letra I no aparece en apellidos
# letra F no aparece en apellidos
# letra W no aparece en apellidos
# letra K no aparece en apellidos
# letra Q no aparece en apellidos
# letra E no aparece en apellidos
# letra O aparece en apellidos
# letra G aparece en apellidos
# letra H no aparece en apellidos
# letra P aparece en apellidos
# letra O aparece en apellidos
# letra R aparece en apellidos
# letra O aparece en apellidos
# letra R aparece en apellidos
# letra W no aparece en apellidos
# letra X no aparece en apellidos
# letra N aparece en apellidos
# letra A aparece en apellidos
# letra X no aparece en apellidos
# letra I no aparece en apellidos
# letra K no aparece en apellidos
# letra Z aparece en apellidos
# letra T aparece en apellidos
# letra E no aparece en apellidos
# letra N aparece en apellidos
# letra B no aparece en apellidos
# letra C no aparece en apellidos
# letra R aparece en apellidos
# letra I no aparece en apellidos
# letra X no aparece en apellidos
# letra E no aparece en apellidos
# letra T aparece en apellidos
# letra X no aparece en apellidos
# letra D no aparece en apellidos
# letra W no aparece en apellidos
# letra X no aparece en apellidos
# letra H no aparece en apellidos
# letra V no aparece en apellidos
# letra H no aparece en apellidos
# letra O aparece en apellidos
# letra R aparece en apellidos
# letra X no aparece en apellidos
# letra O aparece en apellidos
# letra D no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra P aparece en apellidos
# letra E no aparece en apellidos
# letra O aparece en apellidos
# letra L no aparece en apellidos
# letra O aparece en apellidos
# letra T aparece en apellidos
# letra J no aparece en apellidos
# letra Q no aparece en apellidos
# letra D no aparece en apellidos
# letra C no aparece en apellidos
# letra E no aparece en apellidos
# letra N aparece en apellidos
# letra K no aparece en apellidos
# letra Q no aparece en apellidos
# letra L no aparece en apellidos
# letra I no aparece en apellidos
# letra T aparece en apellidos
# letra Y no aparece en apellidos
# letra E no aparece en apellidos
# letra U no aparece en apellidos
# letra E no aparece en apellidos
# letra J no aparece en apellidos
# letra B no aparece en apellidos
# letra F no aparece en apellidos
# letra N aparece en apellidos
# letra P aparece en apellidos
# letra T aparece en apellidos
# letra D no aparece en apellidos
# letra P aparece en apellidos
# letra Q no aparece en apellidos
# letra S no aparece en apellidos
# letra E no aparece en apellidos
# letra S no aparece en apellidos
# letra S no aparece en apellidos
# letra S no aparece en apellidos
# letra X no aparece en apellidos
# letra J no aparece en apellidos
# letra F no aparece en apellidos
# letra H no aparece en apellidos
# letra G aparece en apellidos
# letra H no aparece en apellidos
# letra S no aparece en apellidos
# letra T aparece en apellidos
# letra B no aparece en apellidos
# letra M no aparece en apellidos
# letra N aparece en apellidos
# letra C no aparece en apellidos
# letra T aparece en apellidos
# letra Y no aparece en apellidos
# letra F no aparece en apellidos
# letra R aparece en apellidos
# letra N aparece en apellidos
# letra G aparece en apellidos
# letra Q no aparece en apellidos
# letra J no aparece en apellidos
# letra N aparece en apellidos
# letra P aparece en apellidos
# letra C no aparece en apellidos
# letra U no aparece en apellidos
# letra K no aparece en apellidos
# letra V no aparece en apellidos
# letra Q no aparece en apellidos
# letra E no aparece en apellidos
# letra F no aparece en apellidos
# letra J no aparece en apellidos
# letra Y no aparece en apellidos
# letra Z aparece en apellidos
# letra G aparece en apellidos
# letra I no aparece en apellidos
# letra Y no aparece en apellidos
# letra B no aparece en apellidos
# letra O aparece en apellidos
# letra B no aparece en apellidos
# letra G aparece en apellidos
# letra A aparece en apellidos
# letra H no aparece en apellidos
# letra Z aparece en apellidos
# letra I no aparece en apellidos
# letra Y no aparece en apellidos
# letra Q no aparece en apellidos
# letra H no aparece en apellidos
# letra M no aparece en apellidos
# letra Y no aparece en apellidos
# letra S no aparece en apellidos
# letra O aparece en apellidos
# letra L no aparece en apellidos
# letra P aparece en apellidos
# letra A aparece en apellidos
# letra U no aparece en apellidos
# letra R aparece en apellidos
# letra A aparece en apellidos
# letra U no aparece en apellidos
# letra N aparece en apellidos
# letra U no aparece en apellidos
# letra U no aparece en apellidos
# letra B no aparece en apellidos
# letra O aparece en apellidos
# letra H no aparece en apellidos
# letra J no aparece en apellidos
# letra J no aparece en apellidos
# letra I no aparece en apellidos
# letra G aparece en apellidos
# letra P aparece en apellidos
# letra H no aparece en apellidos
# letra G aparece en apellidos
# letra U no aparece en apellidos
# letra U no aparece en apellidos
# letra W no aparece en apellidos
# letra Q no aparece en apellidos
# letra E no aparece en apellidos
# letra P aparece en apellidos
# letra M no aparece en apellidos
# letra J no aparece en apellidos
# letra T aparece en apellidos
# letra L no aparece en apellidos
# letra S no aparece en apellidos
# letra N aparece en apellidos
# letra P aparece en apellidos
# letra D no aparece en apellidos
# letra X no aparece en apellidos
# letra M no aparece en apellidos
# letra A aparece en apellidos
# letra T aparece en apellidos
# letra L no aparece en apellidos
# letra W no aparece en apellidos
# letra P aparece en apellidos
# letra Q no aparece en apellidos
# letra T aparece en apellidos
# letra L no aparece en apellidos
# letra E no aparece en apellidos
# letra W no aparece en apellidos
# letra C no aparece en apellidos
# letra K no aparece en apellidos
# letra M no aparece en apellidos
# letra T aparece en apellidos
# letra E no aparece en apellidos
# letra T aparece en apellidos
# letra P aparece en apellidos
# letra V no aparece en apellidos
# letra J no aparece en apellidos
# letra E no aparece en apellidos
# letra C no aparece en apellidos
# letra R aparece en apellidos
# letra T aparece en apellidos
# letra U no aparece en apellidos
# letra W no aparece en apellidos
# letra T aparece en apellidos
# letra X no aparece en apellidos
# letra R aparece en apellidos
# letra Y no aparece en apellidos
# letra K no aparece en apellidos
# letra M no aparece en apellidos
# letra Z aparece en apellidos
# letra V no aparece en apellidos
# letra G aparece en apellidos
# letra L no aparece en apellidos
# letra A aparece en apellidos
# letra Q no aparece en apellidos
# letra X no aparece en apellidos
# letra G aparece en apellidos
# letra A aparece en apellidos
# letra A aparece en apellidos
# letra O aparece en apellidos
# letra I no aparece en apellidos
# letra L no aparece en apellidos
# letra X no aparece en apellidos
# letra M no aparece en apellidos
# letra Z aparece en apellidos
# letra J no aparece en apellidos
# letra V no aparece en apellidos
# letra V no aparece en apellidos
# letra L no aparece en apellidos
# letra H no aparece en apellidos
# letra C no aparece en apellidos
# letra X no aparece en apellidos
# letra Y no aparece en apellidos
# letra D no aparece en apellidos
# letra U no aparece en apellidos
# letra I no aparece en apellidos
# letra Q no aparece en apellidos
# letra J no aparece en apellidos
# letra G aparece en apellidos
# letra U no aparece en apellidos
# letra X no aparece en apellidos
# letra P aparece en apellidos
# letra T aparece en apellidos
# letra T aparece en apellidos
# letra Y no aparece en apellidos
# letra G aparece en apellidos
# letra K no aparece en apellidos
# letra S no aparece en apellidos
# letra N aparece en apellidos
# letra M no aparece en apellidos
# letra G aparece en apellidos
# letra L no aparece en apellidos
# letra X no aparece en apellidos
# letra L no aparece en apellidos
# letra V no aparece en apellidos
# letra P aparece en apellidos
# letra K no aparece en apellidos
# letra W no aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra Q no aparece en apellidos
# letra S no aparece en apellidos
# letra H no aparece en apellidos
# letra W no aparece en apellidos
# letra O aparece en apellidos
# letra Y no aparece en apellidos
# letra L no aparece en apellidos
# letra T aparece en apellidos
# letra G aparece en apellidos
# letra E no aparece en apellidos
# letra J no aparece en apellidos
# letra Q no aparece en apellidos
# letra N aparece en apellidos
# letra T aparece en apellidos
# letra M no aparece en apellidos
# letra O aparece en apellidos
# letra A aparece en apellidos
# letra T aparece en apellidos
# letra N aparece en apellidos
# letra F no aparece en apellidos
# letra P aparece en apellidos
# letra U no aparece en apellidos
# letra H no aparece en apellidos
# letra O aparece en apellidos
# letra S no aparece en apellidos
# letra J no aparece en apellidos
# letra O aparece en apellidos
# letra B no aparece en apellidos
# letra F no aparece en apellidos
# letra E no aparece en apellidos
# letra F no aparece en apellidos
# letra A aparece en apellidos
# letra Q no aparece en apellidos
# letra C no aparece en apellidos
# letra S no aparece en apellidos
# letra F no aparece en apellidos
# letra C no aparece en apellidos
# letra V no aparece en apellidos
# letra T aparece en apellidos
# letra N aparece en apellidos
# letra E no aparece en apellidos
# letra L no aparece en apellidos
# letra A aparece en apellidos
# letra K no aparece en apellidos
# letra M no aparece en apellidos
# letra R aparece en apellidos
# letra S no aparece en apellidos
# letra Y no aparece en apellidos
# letra V no aparece en apellidos
# letra S no aparece en apellidos
# letra M no aparece en apellidos
# letra O aparece en apellidos
# letra L no aparece en apellidos
# letra D no aparece en apellidos
# letra P aparece en apellidos
# letra W no aparece en apellidos
# letra O aparece en apellidos
# letra E no aparece en apellidos
# letra J no aparece en apellidos
# letra T aparece en apellidos
# letra D no aparece en apellidos
# letra C no aparece en apellidos
# letra T aparece en apellidos
# letra S no aparece en apellidos
# letra A aparece en apellidos
# array([[0.13333333, 0.53333333, 0.2       , ..., 0.        , 0.53333333,
#         0.        ],
#        [0.33333333, 0.8       , 0.2       , ..., 0.13333333, 0.53333333,
#         0.26666667],
#        [0.26666667, 0.73333333, 0.4       , ..., 0.2       , 0.46666667,
#         0.2       ],
#        ...,
#        [0.4       , 0.6       , 0.4       , ..., 0.13333333, 0.8       ,
#         0.13333333],
#        [0.13333333, 0.2       , 0.26666667, ..., 0.06666667, 0.6       ,
#         0.33333333],
#        [0.26666667, 0.6       , 0.4       , ..., 0.13333333, 0.46666667,
#         0.13333333]])

# %%
X_original = X

Nsamples = X.shape[0]
Ntrain   = int(0.7*Nsamples)
Nval     = int(0.15*Nsamples)
Ntest    = Nsamples-Ntrain-Nval

X_test = X[(Nsamples-Ntest):Nsamples,:]
y_test = y[(Nsamples-Ntest):Nsamples  ]

Xv = X[0:(Nsamples-Ntest),:]
yv = y[0:(Nsamples-Ntest)  ]

# %%
def derivating(fx):
    difcoefs = [1,-1]
    return np.convolve(fx,difcoefs,mode='same')

def chunkIt(seq, num):
    avg = len(seq) / float(num)
    out = []
    last = 0.0

    while last < len(seq):
        out.append(seq[int(last):int(last + avg)])
        last += avg

    return out

def clearList(L): #arroja una lista de L elementos vacios, no sabia de qué otra forma hacerla
    listica = []
    for i in range(0,L):
        listica.append([]);
    return listica

def sigmoid(x):
    return 1/(1+np.exp(-x))

def Perceptron_training(X,y,iteraciones=500,de_min=0.01):
    w_array     = []
    p_i         = []
    
    w_          = np.zeros(X.shape[1] + 1,)
    n           = X.shape[0]
    nf          = X.shape[1]
    sw          = 0
    j           = 0
    index       = []
    error_array = []
    
    while j < iteraciones and sw == 0:
        for i in range(0,n):
            g1  = np.sum(w_*np.insert(X[i,:],0,1))
            yp  = 2*sigmoid(g1)-1
            if yp*y[i] <= 0:
                w_ = w_ + np.insert(X[i,:],0,1)*y[i]
        
        w_array.append(w_)
        predicted = []
        for i in range(0,n):
            predicted.append(Predict(X[i,:],w_))
        p_i.append(predicted)
        E = 0
        for i in range(0,n):
            if predicted[i]*y[i]<0:
                E += -predicted[i]*y[i]
        index.append(j)
        error_array.append(E)
        
        j = j + 1
    plt.plot(error_array,'b')
    plt.title('función de error')
    plt.xlabel('Iteraciones')
    plt.show()
    
    iter_min = np.argmin(error_array)
    print('iteracción óptima: '+str(iter_min)+ ', función de error: '+str(error_array[iter_min]))
    return [w_array[iter_min],p_i[iter_min],E]

def Predict(X,w_):
    g = np.dot(w_.T,np.insert(X,0,1))
    return 2*sigmoid(g)-1

# %% [markdown]
# ### Entrenamiento de la red neuronal usando validación cruzada

# %%
from sklearn.model_selection import KFold
X = Xv
y = yv
Nf = 10
N  = X.shape[0]
kf = KFold(n_splits=Nf)

error_train = np.zeros((Nf,))
error_val   = np.zeros((Nf,))
k=0
error_min = np.inf
for train_index, test_index in kf.split(X):
    predicted1  = np.empty((Nf,))
    predicted2  = np.empty((Nf,))
    [wPerceptron,predicted1,E] = Perceptron_training(X[train_index],y[train_index],iteraciones=50)
    error1 = np.sum(np.array(predicted1)*y[train_index] > 0)/y[train_index].shape[0]

    predicted2 = []
    for j in range(0,X[test_index].shape[0]):
        predicted2.append(Predict(X[test_index][j,:],wPerceptron))
    error2 = np.sum(np.array(predicted2)*y[test_index] > 0)/y[test_index].shape[0]

    if(error2 < error_min):
        wPerceptron_optimo = wPerceptron
        error_min = error2
        index_max = k
    print('validación ',(k+1),' Función de error: ',str(E))
    error_train[k,] = error1
    error_val[k,]  = error2
    k+=1
# Out:
# iteracción óptima: 14, función de error: 1899.0953415718961
# validación  1  Función de error:  3112.4435510984795
# iteracción óptima: 6, función de error: 1793.2818096723042
# validación  2  Función de error:  3872.1215503839817
# iteracción óptima: 7, función de error: 1675.4828692353976
# validación  3  Función de error:  2623.520595530439
# iteracción óptima: 3, función de error: 1914.0218906291802
# validación  4  Función de error:  3177.0560362881433
# iteracción óptima: 39, función de error: 1655.1647023729515
# validación  5  Función de error:  3010.7193523148785
# iteracción óptima: 4, función de error: 1712.8321357273328
# validación  6  Función de error:  2991.671058100079
# iteracción óptima: 3, función de error: 1834.3466413349654
# validación  7  Función de error:  3005.7543384946707
# iteracción óptima: 11, función de error: 1791.6963142010109
# validación  8  Función de error:  2880.659769207634
# iteracción óptima: 49, función de error: 1801.2818584287309
# validación  9  Función de error:  1801.2818584287309
# iteracción óptima: 44, función de error: 1715.0392902327555
# validación  10  Función de error:  1737.1001076164916

# %%
Accuracy_train = np.mean(error_train)
Accuracy_val   = np.mean(error_val  )

print('tasa de entrenamiento: '+ str(Accuracy_train)+', tasa de validación: '+str(Accuracy_val))
# Out:
# tasa de entrenamiento: 0.7116013071895424, tasa de validación: 0.7110588235294119

# %%
#utilizando la toopología óptima
predicted_testing = []
for j in range(0,X_test.shape[0]):
    predicted_testing.append(Predict(X_test[j,:],wPerceptron_optimo))
Accuracy_test = np.sum(np.array(predicted_testing)*y_test > 0)/y_test.shape[0]
print('tasa de testeo: '+ str(Accuracy_test))
# Out:
# tasa de testeo: 0.6393333333333333
